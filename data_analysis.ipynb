# %%
import os
import matplotlib.pyplot as plt

# %%
from torchvision import transforms

transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

# %% [markdown]
# # PlantVillage

# %%
from torchvision.datasets import ImageFolder

data_dir = 'data/PlantVillage'
dataset = ImageFolder(root=data_dir, transform=transform)

# %%
from torch.utils.data import DataLoader

# create a data loader to load images
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
def show_images(images, labels, classes):
    plt.figure(figsize=(12, 6))
    for i in range(min(8, len(images))):
        plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].permute(1, 2, 0))
        plt.title(classes[labels[i]])
        plt.axis('off')
    plt.show()

sample_batch = next(iter(data_loader))

show_images(sample_batch[0], sample_batch[1], dataset.classes)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class_counts = np.bincount(dataset.targets)
class_labels = dataset.classes

#histogram
plt.figure(figsize=(10, 5))
sns.barplot(x=class_labels, y=class_counts, hue=class_labels)
plt.title('PlantVillage Dataset')
plt.xticks()
plt.show()

# %% [markdown]
# # PlantDoc

# %%
from torchvision.datasets import ImageFolder

data_dir = 'data/PlantDoc/train'
dataset = ImageFolder(root=data_dir, transform=transform)

# %%
from torch.utils.data import DataLoader

# create a data loader to load images
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
def show_images(images, labels, classes):
    plt.figure(figsize=(12, 6))
    for i in range(min(8, len(images))):
        plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].permute(1, 2, 0))
        plt.title(classes[labels[i]])
        plt.axis('off')
    plt.show()

sample_batch = next(iter(data_loader))

show_images(sample_batch[0], sample_batch[1], dataset.classes)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class_counts = np.bincount(dataset.targets)
class_labels = dataset.classes

#histogram
plt.figure(figsize=(10, 5))
sns.barplot(x=class_labels, y=class_counts, hue=class_labels)
plt.title('PlantVillage Dataset')
plt.xticks()
plt.show()

# %% [markdown]
# # Hojas Sanas

# %%
from torchvision.datasets import ImageFolder

data_dir = 'data/potato_uncontrolled'
dataset = ImageFolder(root=data_dir, transform=transform)

# %%
from torch.utils.data import DataLoader

# create a data loader to load images
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
def show_images(images, labels, classes):
    plt.figure(figsize=(12, 6))
    for i in range(min(8, len(images))):
        plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].permute(1, 2, 0))
        plt.title(classes[labels[i]])
        plt.axis('off')
    plt.show()

sample_batch = next(iter(data_loader))

show_images(sample_batch[0], sample_batch[1], dataset.classes)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class_counts = np.bincount(dataset.targets)
class_labels = dataset.classes

#histogram
plt.figure(figsize=(10, 5))
sns.barplot(x=class_labels, y=class_counts, hue=class_labels)
plt.title('PlantVillage Dataset')
plt.xticks()
plt.show()
